# %% [markdown]
# <a href="https://colab.research.google.com/github/jkeo180/Basic-messaging/blob/main/Hacklahoma%20-ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -qU "langchain[anthropic]"
from nltk.tokenize import word_tokenize, sent_tokenize
import spacy
import getpass
import os

if not os.environ.get("ANTHROPIC_API_KEY"):
  os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter API key for Anthropic: ")

from langchain.chat_models import init_chat_model
from chatterbot import ChatBot
from langchain_core.messages import HumanMessage, AIMessage

model = init_chat_model("claude-3-5-sonnet-latest", model_provider="anthropic")
chatbot = ChatBot('MyChatbot')

model.invoke([HumanMessage(content="Hi! I'm Julie!")])

# AIMessage(content='Hi Julie! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 11, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0705bf87c0', 'finish_reason': 'stop', 'logprobs': None}, id='run-5211544f-da9f-4325-8b8e-b3d92b2fc71a-0', usage_metadata={'input_tokens': 11, 'output_tokens': 10, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
# !python -m chatterbot_corpus.download
# from chatterbot import ChatBot
# from chatterbot.trainers import ListTrainer

# chatbot = ChatBot('MyChatbot')
# trainer = ListTrainer(chatbot)
# trainer.train([
#                   "Hi there!",
#                   "Hello!",
#                   "How are you?",
#                   "I'm good, thanks for asking."
# ])
# response = chatbot.get_response("How are you?")
# print(response)

# # Note: You need to set your OpenAI API key before running this part.
# # openai.api_key = "YOUR_OPENAI_API_KEY"


# def get_llm_response(prompt):
#               response = openai.Completion.create(
#          engine="text-davinci-003",
#          prompt=prompt,
#          max_tokens=150
#      )
#   from langchain_core.messages import AIMessage

# model.invoke(
#   [
#       HumanMessage(content="Hi! I'm Bob"),
#       AIMessage(content="Hello Bob! How can I assist you today?"),
#       HumanMessage(content="What's my name?"),
#   ]
# )


# # # Example usage of OpenAI (Requires API key to be set)
# # user_input = "How may I help you,today?"
# # chatbot_response = get_llm_response(user_input)
# # print(chatbot_response)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 15.5 MB/s eta 0:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1-2536001231.py in <cell line: 0>()
#       6
#       7 if not os.environ.get("ANTHROPIC_API_KEY"):
# ----> 8   os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter API key for Anthropic: ")
#       9
#      10 from langchain.chat_models import init_chat_model
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# prompt: if user_input.lower() == 'quit':

# %%
# !pip install -q langchain transformers accelerate bitsandbytes gradio langchain_community
# !pip install -q pinecone-client

from langchain.llms import HuggingFacePipeline
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import gradio as gr

model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=512,
    temperature=0.7,
    top_p=0.95,
    repetition_penalty=1.15
)
llm = HuggingFacePipeline(pipeline=pipe)
memory = ConversationBufferMemory()
conversation = ConversationChain(llm=llm, memory=memory, verbose=True)

def chat_with_bot(user_input):
    if user_input.lower() == 'quit':
        return "Goodbye!"
    response = conversation.run(user_input)
    return response

# while True:
#     try:
#         user_input = input("You: ")
#         if user_input.lower() == 'quit':
#             break
#         response = conversation.run(user_input)
#         print(f"Bot: {response}")


iface = gr.Interface(
    fn=chat_with_bot,
    inputs=gr.Textbox(label="Ask HR Assistant", placeholder="Type your question here..."),
    outputs=gr.Textbox(label="Response"),
    title="HR Chatbot: Proof of Concept",
    description="A simple chatbot that could support HR, managers, or employees in the workplace.",
    theme="soft"
)

iface.launch()

    # except (KeyboardInterrupt, EOFError, SystemExit):
    #     break
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 54.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
# ...

# %%
# %pip install chatterbot nltk spacy openai
# !python -m spacy download en_core_web_sm

# %%
# !python -m chatterbot_corpus

# %%
# %pip install langchain langchain-openai
